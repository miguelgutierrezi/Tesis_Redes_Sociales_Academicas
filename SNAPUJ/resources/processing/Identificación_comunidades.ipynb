# %%
# !pip install nltk langdetect spacy networkx gensim python-louvain scikit-learn fuzzywuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 14.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.5.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.1)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.1)
# Requirement already satisfied: python-louvain in /usr/local/lib/python3.10/dist-packages (0.16)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.65.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect) (1.16.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.1.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (6.3.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.22.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.27.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.10.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.2)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993224 sha256=10210ee8b444f1b4f6b39771053f23ecbff7f3fca94be0f1fa93c35fb8cac9fb
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# Installing collected packages: fuzzywuzzy, langdetect
# Successfully installed fuzzywuzzy-0.18.0 langdetect-1.0.9

# %%
# !python -m spacy download es_core_news_md
# Out:
# 2023-05-21 21:57:07.415228: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-21 21:57:08.523699: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting es-core-news-md==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_md-3.5.0/es_core_news_md-3.5.0-py3-none-any.whl (42.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 MB 16.7 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from es-core-news-md==3.5.0) (3.5.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-md==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-md==3.5.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-md==3.5.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-md==3.5.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-md==3.5.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-md==3.5.0) (8.1.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-md==3.5.0) (1.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-md==3.5.0) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-md==3.5.0) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-md==3.5.0) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-md==3.5.0) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-md==3.5.0) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-md==3.5.0) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-md==3.5.0) (1.22.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-md==3.5.0) (2.27.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-md==3.5.0) (1.10.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-md==3.5.0) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-md==3.5.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-md==3.5.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-md==3.5.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->es-core-news-md==3.5.0) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->es-core-news-md==3.5.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->es-core-news-md==3.5.0) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->es-core-news-md==3.5.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->es-core-news-md==3.5.0) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->es-core-news-md==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->es-core-news-md==3.5.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->es-core-news-md==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->es-core-news-md==3.5.0) (2.1.2)
# Installing collected packages: es-core-news-md
# Successfully installed es-core-news-md-3.5.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_md')

# %%
# !python -m spacy download en_core_web_md
# Out:
# 2023-05-21 21:57:24.252512: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-21 21:57:25.816708: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-md==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.5.0/en_core_web_md-3.5.0-py3-none-any.whl (42.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from en-core-web-md==3.5.0) (3.5.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (8.1.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.22.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.27.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.10.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.1.2)
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-3.5.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
import json
from itertools import combinations

import networkx as nx
import nltk
import pandas as pd
import spacy
from community import community_louvain
from langdetect import detect
from nltk import pos_tag
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
nlp_en = spacy.load('en_core_web_md')
nlp_es = spacy.load('es_core_news_md')
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
stopwords_en = stopwords.words('english')
stopwords_es = stopwords.words('spanish')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
def load_file(name):
    with open(name, 'r') as file:
        return json.load(file)

# %%
def get_author_key(author_dict, name):
    for key, value in author_dict.items():
        if name in value:
            return key
    return ""

# %%
def get_relevant_words(lang, word_list):
    relevant_words = []
    if lang == 'es':
        nlp = nlp_es
    else:
        nlp = nlp_en
    for word in word_list:
        doc = nlp(word)
        for token in doc:
            if token.pos_ == 'NOUN' or token.pos_ == 'VERB':
                relevant_words.append(token.lemma_)
    return relevant_words

# %%
def process_relevant_words(word_list):
    relevant_words = []
    pos_tags = pos_tag(word_list)
    for word, tag in pos_tags:
        if tag.startswith('N') or tag.startswith('V'):
            relevant_words.append(word)
    return relevant_words

# %%
# Generar conceptos de las palabras más representativas identificadas en la comunidad
def generate_concepts(community_keywords):
    concepts = []
    for keywords in community_keywords:
        concept = ' '.join(keywords)
        concepts.append(concept)
    return concepts

# %%
# Extraer palabras más representativas utilizando el vectorizador TfidVectorizer
def extract_representative_keywords(communities, lang, num_keywords=2):
    stop_words = stopwords_es if lang == 'es' else stopwords_en
    community_keywords = []
    for community in communities:
        vectorizer = TfidfVectorizer(stop_words=stop_words)
        community_texts = [''.join(node) for node in community]
        if not community_texts:
            continue
        try:
            tfidf_matrix = vectorizer.fit_transform(community_texts)
        except ValueError as e:
            continue
        feature_names = vectorizer.get_feature_names_out()
        avg_tfidf = tfidf_matrix.mean(axis=0).tolist()[0]
        sorted_keywords = sorted(zip(avg_tfidf, feature_names), reverse=True)[:num_keywords]
        community_keywords.append([keyword for _, keyword in sorted_keywords])
    return community_keywords

# %%
# Identificar comunidades a partir de algoritmo de Louvain
def identify_communities(word_network):
    partition = community_louvain.best_partition(word_network)
    communities = {}
    for node, community in partition.items():
        if community not in communities:
            communities[community] = []
        communities[community].append(node)

    return list(communities.values())

# %%
# Crear red de palabras con NetworkX
# Cada palabra es un nodo y tiene alguna conexión con el resto de palabras que aparecen
def create_word_network(keywords):
    G = nx.Graph()
    for keyword in keywords:
        G.add_node(keyword)
    for pair in combinations(keywords, 2):
        G.add_edge(*pair)
    return G

# %%
# Identificar palabras clave de acuerdo al idioma
def identify_keywords(text, lang):
    if lang == 'es':
        nlp = nlp_es
        stop_words = stopwords_es
    else:
        nlp = nlp_en
        stop_words = stopwords_en
    doc = nlp(text)
    keywords = []
    for token in doc:
        if token.text.lower() not in stop_words and token.is_alpha:
            keywords.append(token.lemma_.lower())
    return keywords

# %%
# Aplicar lematización tokenización y elminiación de stop words utilizando spaCy
def process_text(text, lang):
    if lang == 'en':
        nlp = spacy.load('en_core_web_md')
    elif lang == 'es':
        nlp = spacy.load('es_core_news_md')
    else:
        return None

    doc = nlp(text)
    return doc

# %%
def process_document_description(description):
    description_lang = detect(description)
    processed_text = process_text(description, description_lang)
    if processed_text is not None:
        keywords = identify_keywords(processed_text, description_lang)
        word_network = create_word_network(keywords)
        communities = identify_communities(word_network)
        community_keywords = extract_representative_keywords(communities, description_lang)
        concepts = generate_concepts(community_keywords)
        relevant_concepts = process_relevant_words(concepts)
        relevant_topics = get_relevant_words(description_lang, relevant_concepts)
        return concepts
    return None

# %%
authors = load_file('authors.txt')

# %%
def process_data():
  documents = pd.read_csv("papersPreprocessed (2).csv")

  total_documents, columnas = documents.shape
  document_number = 1
  total_communities = []
  total_authors = []

  for index, row in documents.iterrows():
    document = row.to_dict()
    print(f'Procesando documento {document_number}/{total_documents}')
    description = None if pd.isna(document['Abstract']) else document['Abstract']
    communities = []
    if description is not None:
      communities = process_document_description(description)
    document_authors = document['Authors'].split(';')
    disambiguated_authors = []
    for author in document_authors:
      disambiguated_authors.append(get_author_key(authors, author))

    total_authors.append(';'.join(disambiguated_authors))
    total_communities.append(communities)
    document_number = document_number + 1

  documents['communities'] = total_communities
  documents['disambiguated_authors'] = total_authors

  return documents

# %%
documents_df = process_data()
documents_df.to_csv('papersPreprocessedv3.csv', index=False)
# Out:
# Streaming output truncated to the last 5000 lines.
# Procesando documento 3515/10194
# Procesando documento 3516/10194
# Procesando documento 3517/10194
# Procesando documento 3518/10194
# Procesando documento 3519/10194
# Procesando documento 3520/10194
# Procesando documento 3521/10194
# Procesando documento 3522/10194
# Procesando documento 3523/10194
# Procesando documento 3524/10194
# Procesando documento 3525/10194
# Procesando documento 3526/10194
# Procesando documento 3527/10194
# Procesando documento 3528/10194
# Procesando documento 3529/10194
# Procesando documento 3530/10194
# Procesando documento 3531/10194
# Procesando documento 3532/10194
# Procesando documento 3533/10194
# Procesando documento 3534/10194
# Procesando documento 3535/10194
# Procesando documento 3536/10194
# Procesando documento 3537/10194
# Procesando documento 3538/10194
# Procesando documento 3539/10194
# Procesando documento 3540/10194
# Procesando documento 3541/10194
# Procesando documento 3542/10194
# Procesando documento 3543/10194
# Procesando documento 3544/10194
# Procesando documento 3545/10194
# Procesando documento 3546/10194
# Procesando documento 3547/10194
# Procesando documento 3548/10194
# Procesando documento 3549/10194
# Procesando documento 3550/10194
# Procesando documento 3551/10194
# Procesando documento 3552/10194
# Procesando documento 3553/10194
# Procesando documento 3554/10194
# Procesando documento 3555/10194
# Procesando documento 3556/10194
# Procesando documento 3557/10194
# Procesando documento 3558/10194
# Procesando documento 3559/10194
# Procesando documento 3560/10194
# Procesando documento 3561/10194
# Procesando documento 3562/10194
# Procesando documento 3563/10194
# Procesando documento 3564/10194
# Procesando documento 3565/10194
# Procesando documento 3566/10194
# Procesando documento 3567/10194
# Procesando documento 3568/10194
# Procesando documento 3569/10194
# Procesando documento 3570/10194
# Procesando documento 3571/10194
# Procesando documento 3572/10194
# Procesando documento 3573/10194
# Procesando documento 3574/10194
# Procesando documento 3575/10194
# Procesando documento 3576/10194
# Procesando documento 3577/10194
# Procesando documento 3578/10194
# Procesando documento 3579/10194
# Procesando documento 3580/10194
# Procesando documento 3581/10194
# Procesando documento 3582/10194
# Procesando documento 3583/10194
# Procesando documento 3584/10194
# Procesando documento 3585/10194
# Procesando documento 3586/10194
# Procesando documento 3587/10194
# Procesando documento 3588/10194
# Procesando documento 3589/10194
# Procesando documento 3590/10194
# Procesando documento 3591/10194
# Procesando documento 3592/10194
# Procesando documento 3593/10194
# Procesando documento 3594/10194
# Procesando documento 3595/10194
# Procesando documento 3596/10194
# Procesando documento 3597/10194
# Procesando documento 3598/10194
# Procesando documento 3599/10194
# Procesando documento 3600/10194
# Procesando documento 3601/10194
# Procesando documento 3602/10194
# Procesando documento 3603/10194
# Procesando documento 3604/10194
# Procesando documento 3605/10194
# Procesando documento 3606/10194
# Procesando documento 3607/10194
# Procesando documento 3608/10194
# Procesando documento 3609/10194
# Procesando documento 3610/10194
# Procesando documento 3611/10194
# Procesando documento 3612/10194
# Procesando documento 3613/10194
# Procesando documento 3614/10194
# Procesando documento 3615/10194
# Procesando documento 3616/10194
# Procesando documento 3617/10194
# Procesando documento 3618/10194
# Procesando documento 3619/10194
# Procesando documento 3620/10194
# Procesando documento 3621/10194
# Procesando documento 3622/10194
# Procesando documento 3623/10194
# Procesando documento 3624/10194
# Procesando documento 3625/10194
# Procesando documento 3626/10194
# Procesando documento 3627/10194
# Procesando documento 3628/10194
# Procesando documento 3629/10194
# Procesando documento 3630/10194
# Procesando documento 3631/10194
# Procesando documento 3632/10194
# Procesando documento 3633/10194
# Procesando documento 3634/10194
# Procesando documento 3635/10194
# Procesando documento 3636/10194
# Procesando documento 3637/10194
# Procesando documento 3638/10194
# Procesando documento 3639/10194
# Procesando documento 3640/10194
# Procesando documento 3641/10194
# Procesando documento 3642/10194
# Procesando documento 3643/10194
# Procesando documento 3644/10194
# Procesando documento 3645/10194
# Procesando documento 3646/10194
# Procesando documento 3647/10194
# Procesando documento 3648/10194
# Procesando documento 3649/10194
# Procesando documento 3650/10194
# Procesando documento 3651/10194
# Procesando documento 3652/10194
# Procesando documento 3653/10194
# Procesando documento 3654/10194
# Procesando documento 3655/10194
# Procesando documento 3656/10194
# Procesando documento 3657/10194
# Procesando documento 3658/10194
# Procesando documento 3659/10194
# Procesando documento 3660/10194
# Procesando documento 3661/10194
# Procesando documento 3662/10194
# Procesando documento 3663/10194
# Procesando documento 3664/10194
# Procesando documento 3665/10194
# Procesando documento 3666/10194
# Procesando documento 3667/10194
# Procesando documento 3668/10194
# Procesando documento 3669/10194
# Procesando documento 3670/10194
# Procesando documento 3671/10194
# Procesando documento 3672/10194
# Procesando documento 3673/10194
# Procesando documento 3674/10194
# Procesando documento 3675/10194
# Procesando documento 3676/10194
# Procesando documento 3677/10194
# Procesando documento 3678/10194
# Procesando documento 3679/10194
# Procesando documento 3680/10194
# Procesando documento 3681/10194
# Procesando documento 3682/10194
# Procesando documento 3683/10194
# Procesando documento 3684/10194
# Procesando documento 3685/10194
# Procesando documento 3686/10194
# Procesando documento 3687/10194
# Procesando documento 3688/10194
# Procesando documento 3689/10194
# Procesando documento 3690/10194
# Procesando documento 3691/10194
# Procesando documento 3692/10194
# Procesando documento 3693/10194
# Procesando documento 3694/10194
# Procesando documento 3695/10194
# Procesando documento 3696/10194
# Procesando documento 3697/10194
# Procesando documento 3698/10194
# Procesando documento 3699/10194
# Procesando documento 3700/10194
# Procesando documento 3701/10194
# Procesando documento 3702/10194
# Procesando documento 3703/10194
# Procesando documento 3704/10194
# Procesando documento 3705/10194
# Procesando documento 3706/10194
# Procesando documento 3707/10194
# Procesando documento 3708/10194
# Procesando documento 3709/10194
# Procesando documento 3710/10194
# Procesando documento 3711/10194
# Procesando documento 3712/10194
# Procesando documento 3713/10194
# Procesando documento 3714/10194
# Procesando documento 3715/10194
# Procesando documento 3716/10194
# Procesando documento 3717/10194
# Procesando documento 3718/10194
# Procesando documento 3719/10194
# Procesando documento 3720/10194
# Procesando documento 3721/10194
# Procesando documento 3722/10194
# Procesando documento 3723/10194
# Procesando documento 3724/10194
# Procesando documento 3725/10194
# Procesando documento 3726/10194
# Procesando documento 3727/10194
# Procesando documento 3728/10194
# Procesando documento 3729/10194
# Procesando documento 3730/10194
# Procesando documento 3731/10194
# Procesando documento 3732/10194
# Procesando documento 3733/10194
# Procesando documento 3734/10194
# Procesando documento 3735/10194
# Procesando documento 3736/10194
# Procesando documento 3737/10194
# Procesando documento 3738/10194
# Procesando documento 3739/10194
# Procesando documento 3740/10194
# Procesando documento 3741/10194
# Procesando documento 3742/10194
# Procesando documento 3743/10194
# Procesando documento 3744/10194
# Procesando documento 3745/10194
# Procesando documento 3746/10194
# Procesando documento 3747/10194
# Procesando documento 3748/10194
# Procesando documento 3749/10194
# Procesando documento 3750/10194
# Procesando documento 3751/10194
# Procesando documento 3752/10194
# Procesando documento 3753/10194
# Procesando documento 3754/10194
# Procesando documento 3755/10194
# Procesando documento 3756/10194
# Procesando documento 3757/10194
# Procesando documento 3758/10194
# Procesando documento 3759/10194
# Procesando documento 3760/10194
# Procesando documento 3761/10194
# Procesando documento 3762/10194
# Procesando documento 3763/10194
# Procesando documento 3764/10194
# Procesando documento 3765/10194
# Procesando documento 3766/10194
# Procesando documento 3767/10194
# Procesando documento 3768/10194
# Procesando documento 3769/10194
# Procesando documento 3770/10194
# Procesando documento 3771/10194
# Procesando documento 3772/10194
# Procesando documento 3773/10194
# Procesando documento 3774/10194
# Procesando documento 3775/10194
# Procesando documento 3776/10194
# Procesando documento 3777/10194
# Procesando documento 3778/10194
# Procesando documento 3779/10194
# Procesando documento 3780/10194
# Procesando documento 3781/10194
# Procesando documento 3782/10194
# Procesando documento 3783/10194
# Procesando documento 3784/10194
# Procesando documento 3785/10194
# Procesando documento 3786/10194
# Procesando documento 3787/10194
# Procesando documento 3788/10194
# Procesando documento 3789/10194
# Procesando documento 3790/10194
# Procesando documento 3791/10194
# Procesando documento 3792/10194
# Procesando documento 3793/10194
# Procesando documento 3794/10194
# Procesando documento 3795/10194
# Procesando documento 3796/10194
# Procesando documento 3797/10194
# Procesando documento 3798/10194
# Procesando documento 3799/10194
# Procesando documento 3800/10194
# Procesando documento 3801/10194
# Procesando documento 3802/10194
# Procesando documento 3803/10194
# Procesando documento 3804/10194
# Procesando documento 3805/10194
# Procesando documento 3806/10194
# Procesando documento 3807/10194
# Procesando documento 3808/10194
# Procesando documento 3809/10194
# Procesando documento 3810/10194
# Procesando documento 3811/10194
# Procesando documento 3812/10194
# Procesando documento 3813/10194
# Procesando documento 3814/10194
# Procesando documento 3815/10194
# Procesando documento 3816/10194
# Procesando documento 3817/10194
# Procesando documento 3818/10194
# Procesando documento 3819/10194
# Procesando documento 3820/10194
# Procesando documento 3821/10194
# Procesando documento 3822/10194
# Procesando documento 3823/10194
# Procesando documento 3824/10194
# Procesando documento 3825/10194
# Procesando documento 3826/10194
# Procesando documento 3827/10194
# Procesando documento 3828/10194
# Procesando documento 3829/10194
# Procesando documento 3830/10194
# Procesando documento 3831/10194
# Procesando documento 3832/10194
# Procesando documento 3833/10194
# Procesando documento 3834/10194
# Procesando documento 3835/10194
# Procesando documento 3836/10194
# Procesando documento 3837/10194
# Procesando documento 3838/10194
# Procesando documento 3839/10194
# Procesando documento 3840/10194
# Procesando documento 3841/10194
# Procesando documento 3842/10194
# Procesando documento 3843/10194
# Procesando documento 3844/10194
# Procesando documento 3845/10194
# Procesando documento 3846/10194
# Procesando documento 3847/10194
# Procesando documento 3848/10194
# Procesando documento 3849/10194
# Procesando documento 3850/10194
# Procesando documento 3851/10194
# Procesando documento 3852/10194
# Procesando documento 3853/10194
# Procesando documento 3854/10194
# Procesando documento 3855/10194
# Procesando documento 3856/10194
# Procesando documento 3857/10194
# Procesando documento 3858/10194
# Procesando documento 3859/10194
# Procesando documento 3860/10194
# Procesando documento 3861/10194
# Procesando documento 3862/10194
# Procesando documento 3863/10194
# Procesando documento 3864/10194
# Procesando documento 3865/10194
# Procesando documento 3866/10194
# Procesando documento 3867/10194
# Procesando documento 3868/10194
# Procesando documento 3869/10194
# Procesando documento 3870/10194
# Procesando documento 3871/10194
# Procesando documento 3872/10194
# Procesando documento 3873/10194
# Procesando documento 3874/10194
# Procesando documento 3875/10194
# Procesando documento 3876/10194
# Procesando documento 3877/10194
# Procesando documento 3878/10194
# Procesando documento 3879/10194
# Procesando documento 3880/10194
# Procesando documento 3881/10194
# Procesando documento 3882/10194
# Procesando documento 3883/10194
# Procesando documento 3884/10194
# Procesando documento 3885/10194
# Procesando documento 3886/10194
# Procesando documento 3887/10194
# Procesando documento 3888/10194
# Procesando documento 3889/10194
# Procesando documento 3890/10194
# Procesando documento 3891/10194
# Procesando documento 3892/10194
# Procesando documento 3893/10194
# Procesando documento 3894/10194
# Procesando documento 3895/10194
# Procesando documento 3896/10194
# Procesando documento 3897/10194
# Procesando documento 3898/10194
# Procesando documento 3899/10194
# Procesando documento 3900/10194
# Procesando documento 3901/10194
# Procesando documento 3902/10194
# Procesando documento 3903/10194
# Procesando documento 3904/10194
# Procesando documento 3905/10194
# Procesando documento 3906/10194
# Procesando documento 3907/10194
# Procesando documento 3908/10194
# Procesando documento 3909/10194
# Procesando documento 3910/10194
# Procesando documento 3911/10194
# Procesando documento 3912/10194
# Procesando documento 3913/10194
# Procesando documento 3914/10194
# Procesando documento 3915/10194
# Procesando documento 3916/10194
# Procesando documento 3917/10194
# Procesando documento 3918/10194
# Procesando documento 3919/10194
# Procesando documento 3920/10194
# Procesando documento 3921/10194
# Procesando documento 3922/10194
# Procesando documento 3923/10194
# Procesando documento 3924/10194
# Procesando documento 3925/10194
# Procesando documento 3926/10194
# Procesando documento 3927/10194
# Procesando documento 3928/10194
# Procesando documento 3929/10194
# Procesando documento 3930/10194
# Procesando documento 3931/10194
# Procesando documento 3932/10194
# Procesando documento 3933/10194
# Procesando documento 3934/10194
# Procesando documento 3935/10194
# Procesando documento 3936/10194
# Procesando documento 3937/10194
# Procesando documento 3938/10194
# Procesando documento 3939/10194
# Procesando documento 3940/10194
# Procesando documento 3941/10194
# Procesando documento 3942/10194
# Procesando documento 3943/10194
# Procesando documento 3944/10194
# Procesando documento 3945/10194
# Procesando documento 3946/10194
# Procesando documento 3947/10194
# Procesando documento 3948/10194
# Procesando documento 3949/10194
# Procesando documento 3950/10194
# Procesando documento 3951/10194
# Procesando documento 3952/10194
# Procesando documento 3953/10194
# Procesando documento 3954/10194
# Procesando documento 3955/10194
# Procesando documento 3956/10194
# Procesando documento 3957/10194
# Procesando documento 3958/10194
# Procesando documento 3959/10194
# Procesando documento 3960/10194
# Procesando documento 3961/10194
# Procesando documento 3962/10194
# Procesando documento 3963/10194
# Procesando documento 3964/10194
# Procesando documento 3965/10194
# Procesando documento 3966/10194
# Procesando documento 3967/10194
# Procesando documento 3968/10194
# Procesando documento 3969/10194
# Procesando documento 3970/10194
# Procesando documento 3971/10194
# Procesando documento 3972/10194
# Procesando documento 3973/10194
# Procesando documento 3974/10194
# Procesando documento 3975/10194
# Procesando documento 3976/10194
# Procesando documento 3977/10194
# Procesando documento 3978/10194
# Procesando documento 3979/10194
# Procesando documento 3980/10194
# Procesando documento 3981/10194
# Procesando documento 3982/10194
# Procesando documento 3983/10194
# Procesando documento 3984/10194
# Procesando documento 3985/10194
# Procesando documento 3986/10194
# Procesando documento 3987/10194
# Procesando documento 3988/10194
# Procesando documento 3989/10194
# Procesando documento 3990/10194
# Procesando documento 3991/10194
# Procesando documento 3992/10194
# Procesando documento 3993/10194
# Procesando documento 3994/10194
# Procesando documento 3995/10194
# Procesando documento 3996/10194
# Procesando documento 3997/10194
# Procesando documento 3998/10194
# Procesando documento 3999/10194
# Procesando documento 4000/10194
# Procesando documento 4001/10194
# Procesando documento 4002/10194
# Procesando documento 4003/10194
# Procesando documento 4004/10194
# Procesando documento 4005/10194
# Procesando documento 4006/10194
# Procesando documento 4007/10194
# Procesando documento 4008/10194
# Procesando documento 4009/10194
# Procesando documento 4010/10194
# Procesando documento 4011/10194
# Procesando documento 4012/10194
# Procesando documento 4013/10194
# Procesando documento 4014/10194
# Procesando documento 4015/10194
# Procesando documento 4016/10194
# Procesando documento 4017/10194
# Procesando documento 4018/10194
# Procesando documento 4019/10194
# Procesando documento 4020/10194
# Procesando documento 4021/10194
# Procesando documento 4022/10194
# Procesando documento 4023/10194
# Procesando documento 4024/10194
# Procesando documento 4025/10194
# Procesando documento 4026/10194
# Procesando documento 4027/10194
# Procesando documento 4028/10194
# Procesando documento 4029/10194
# Procesando documento 4030/10194
# Procesando documento 4031/10194
# Procesando documento 4032/10194
# Procesando documento 4033/10194
# Procesando documento 4034/10194
# Procesando documento 4035/10194
# Procesando documento 4036/10194
# Procesando documento 4037/10194
# Procesando documento 4038/10194
# Procesando documento 4039/10194
# Procesando documento 4040/10194
# Procesando documento 4041/10194
# Procesando documento 4042/10194
# Procesando documento 4043/10194
# Procesando documento 4044/10194
# Procesando documento 4045/10194
# Procesando documento 4046/10194
# Procesando documento 4047/10194
# Procesando documento 4048/10194
# Procesando documento 4049/10194
# Procesando documento 4050/10194
# Procesando documento 4051/10194
# Procesando documento 4052/10194
# Procesando documento 4053/10194
# Procesando documento 4054/10194
# Procesando documento 4055/10194
# Procesando documento 4056/10194
# Procesando documento 4057/10194
# Procesando documento 4058/10194
# Procesando documento 4059/10194
# Procesando documento 4060/10194
# Procesando documento 4061/10194
# Procesando documento 4062/10194
# Procesando documento 4063/10194
# Procesando documento 4064/10194
# Procesando documento 4065/10194
# Procesando documento 4066/10194
# Procesando documento 4067/10194
# Procesando documento 4068/10194
# Procesando documento 4069/10194
# Procesando documento 4070/10194
# Procesando documento 4071/10194
# Procesando documento 4072/10194
# Procesando documento 4073/10194
# Procesando documento 4074/10194
# Procesando documento 4075/10194
# Procesando documento 4076/10194
# Procesando documento 4077/10194
# Procesando documento 4078/10194
# Procesando documento 4079/10194
# Procesando documento 4080/10194
# Procesando documento 4081/10194
# Procesando documento 4082/10194
# Procesando documento 4083/10194
# Procesando documento 4084/10194
# Procesando documento 4085/10194
# Procesando documento 4086/10194
# Procesando documento 4087/10194
# Procesando documento 4088/10194
# Procesando documento 4089/10194
# Procesando documento 4090/10194
# Procesando documento 4091/10194
# Procesando documento 4092/10194
# Procesando documento 4093/10194
# Procesando documento 4094/10194
# Procesando documento 4095/10194
# Procesando documento 4096/10194
# Procesando documento 4097/10194
# Procesando documento 4098/10194
# Procesando documento 4099/10194
# Procesando documento 4100/10194
# Procesando documento 4101/10194
# Procesando documento 4102/10194
# Procesando documento 4103/10194
# Procesando documento 4104/10194
# Procesando documento 4105/10194
# Procesando documento 4106/10194
# Procesando documento 4107/10194
# Procesando documento 4108/10194
# Procesando documento 4109/10194
# Procesando documento 4110/10194
# Procesando documento 4111/10194
# Procesando documento 4112/10194
# Procesando documento 4113/10194
# Procesando documento 4114/10194
# Procesando documento 4115/10194
# Procesando documento 4116/10194
# Procesando documento 4117/10194
# Procesando documento 4118/10194
# Procesando documento 4119/10194
# Procesando documento 4120/10194
# Procesando documento 4121/10194
# Procesando documento 4122/10194
# Procesando documento 4123/10194
# Procesando documento 4124/10194
# Procesando documento 4125/10194
# Procesando documento 4126/10194
# Procesando documento 4127/10194
# Procesando documento 4128/10194
# Procesando documento 4129/10194
# Procesando documento 4130/10194
# Procesando documento 4131/10194
# Procesando documento 4132/10194
# Procesando documento 4133/10194
# Procesando documento 4134/10194
# Procesando documento 4135/10194
# Procesando documento 4136/10194
# Procesando documento 4137/10194
# Procesando documento 4138/10194
# Procesando documento 4139/10194
# Procesando documento 4140/10194
# Procesando documento 4141/10194
# Procesando documento 4142/10194
# Procesando documento 4143/10194
# Procesando documento 4144/10194
# Procesando documento 4145/10194
# Procesando documento 4146/10194
# Procesando documento 4147/10194
# Procesando documento 4148/10194
# Procesando documento 4149/10194
# Procesando documento 4150/10194
# Procesando documento 4151/10194
# Procesando documento 4152/10194
# Procesando documento 4153/10194
# Procesando documento 4154/10194
# Procesando documento 4155/10194
# Procesando documento 4156/10194
# Procesando documento 4157/10194
# Procesando documento 4158/10194
# Procesando documento 4159/10194
# Procesando documento 4160/10194
# Procesando documento 4161/10194
# Procesando documento 4162/10194
# Procesando documento 4163/10194
# Procesando documento 4164/10194
# Procesando documento 4165/10194
# Procesando documento 4166/10194
# Procesando documento 4167/10194
# Procesando documento 4168/10194
# Procesando documento 4169/10194
# Procesando documento 4170/10194
# Procesando documento 4171/10194
# Procesando documento 4172/10194
# Procesando documento 4173/10194
# Procesando documento 4174/10194
# Procesando documento 4175/10194
# Procesando documento 4176/10194
# Procesando documento 4177/10194
# Procesando documento 4178/10194
# Procesando documento 4179/10194
# Procesando documento 4180/10194
# Procesando documento 4181/10194
# Procesando documento 4182/10194
# Procesando documento 4183/10194
# Procesando documento 4184/10194
# Procesando documento 4185/10194
# Procesando documento 4186/10194
# Procesando documento 4187/10194
# Procesando documento 4188/10194
# Procesando documento 4189/10194
# Procesando documento 4190/10194
# Procesando documento 4191/10194
# Procesando documento 4192/10194
# Procesando documento 4193/10194
# Procesando documento 4194/10194
# Procesando documento 4195/10194
# Procesando documento 4196/10194
# Procesando documento 4197/10194
# Procesando documento 4198/10194
# Procesando documento 4199/10194
# Procesando documento 4200/10194
# Procesando documento 4201/10194
# Procesando documento 4202/10194
# Procesando documento 4203/10194
# Procesando documento 4204/10194
# Procesando documento 4205/10194
# Procesando documento 4206/10194
# Procesando documento 4207/10194
# Procesando documento 4208/10194
# Procesando documento 4209/10194
# Procesando documento 4210/10194
# Procesando documento 4211/10194
# Procesando documento 4212/10194
# Procesando documento 4213/10194
# Procesando documento 4214/10194
# Procesando documento 4215/10194
# Procesando documento 4216/10194
# Procesando documento 4217/10194
# Procesando documento 4218/10194
# Procesando documento 4219/10194
# Procesando documento 4220/10194
# Procesando documento 4221/10194
# Procesando documento 4222/10194
# Procesando documento 4223/10194
# Procesando documento 4224/10194
# Procesando documento 4225/10194
# Procesando documento 4226/10194
# Procesando documento 4227/10194
# Procesando documento 4228/10194
# Procesando documento 4229/10194
# Procesando documento 4230/10194
# Procesando documento 4231/10194
# Procesando documento 4232/10194
# Procesando documento 4233/10194
# Procesando documento 4234/10194
# Procesando documento 4235/10194
# Procesando documento 4236/10194
# Procesando documento 4237/10194
# Procesando documento 4238/10194
# Procesando documento 4239/10194
# Procesando documento 4240/10194
# Procesando documento 4241/10194
# Procesando documento 4242/10194
# Procesando documento 4243/10194
# Procesando documento 4244/10194
# Procesando documento 4245/10194
# Procesando documento 4246/10194
# Procesando documento 4247/10194
# Procesando documento 4248/10194
# Procesando documento 4249/10194
# Procesando documento 4250/10194
# Procesando documento 4251/10194
# Procesando documento 4252/10194
# Procesando documento 4253/10194
# Procesando documento 4254/10194
# Procesando documento 4255/10194
# Procesando documento 4256/10194
# Procesando documento 4257/10194
# Procesando documento 4258/10194
# Procesando documento 4259/10194
# Procesando documento 4260/10194
# Procesando documento 4261/10194
# Procesando documento 4262/10194
# Procesando documento 4263/10194
# Procesando documento 4264/10194
# Procesando documento 4265/10194
# Procesando documento 4266/10194
# Procesando documento 4267/10194
# Procesando documento 4268/10194
# Procesando documento 4269/10194
# Procesando documento 4270/10194
# Procesando documento 4271/10194
# Procesando documento 4272/10194
# Procesando documento 4273/10194
# Procesando documento 4274/10194
# Procesando documento 4275/10194
# Procesando documento 4276/10194
# Procesando documento 4277/10194
# Procesando documento 4278/10194
# Procesando documento 4279/10194
# Procesando documento 4280/10194
# Procesando documento 4281/10194
# Procesando documento 4282/10194
# Procesando documento 4283/10194
# Procesando documento 4284/10194
# Procesando documento 4285/10194
# Procesando documento 4286/10194
# Procesando documento 4287/10194
# Procesando documento 4288/10194
# Procesando documento 4289/10194
# Procesando documento 4290/10194
# Procesando documento 4291/10194
# Procesando documento 4292/10194
# Procesando documento 4293/10194
# Procesando documento 4294/10194
# Procesando documento 4295/10194
# Procesando documento 4296/10194
# Procesando documento 4297/10194
# Procesando documento 4298/10194
# Procesando documento 4299/10194
# Procesando documento 4300/10194
# Procesando documento 4301/10194
# Procesando documento 4302/10194
# Procesando documento 4303/10194
# Procesando documento 4304/10194
# Procesando documento 4305/10194
# Procesando documento 4306/10194
# Procesando documento 4307/10194
# Procesando documento 4308/10194
# Procesando documento 4309/10194
# Procesando documento 4310/10194
# Procesando documento 4311/10194
# Procesando documento 4312/10194
# Procesando documento 4313/10194
# Procesando documento 4314/10194
# Procesando documento 4315/10194
# Procesando documento 4316/10194
# Procesando documento 4317/10194
# Procesando documento 4318/10194
# Procesando documento 4319/10194
# Procesando documento 4320/10194
# Procesando documento 4321/10194
# Procesando documento 4322/10194
# Procesando documento 4323/10194
# Procesando documento 4324/10194
# Procesando documento 4325/10194
# Procesando documento 4326/10194
# Procesando documento 4327/10194
# Procesando documento 4328/10194
# Procesando documento 4329/10194
# Procesando documento 4330/10194
# Procesando documento 4331/10194
# Procesando documento 4332/10194
# Procesando documento 4333/10194
# Procesando documento 4334/10194
# Procesando documento 4335/10194
# Procesando documento 4336/10194
# Procesando documento 4337/10194
# Procesando documento 4338/10194
# Procesando documento 4339/10194
# Procesando documento 4340/10194
# Procesando documento 4341/10194
# Procesando documento 4342/10194
# Procesando documento 4343/10194
# Procesando documento 4344/10194
# Procesando documento 4345/10194
# Procesando documento 4346/10194
# Procesando documento 4347/10194
# Procesando documento 4348/10194
# Procesando documento 4349/10194
# Procesando documento 4350/10194
# Procesando documento 4351/10194
# Procesando documento 4352/10194
# Procesando documento 4353/10194
# Procesando documento 4354/10194
# Procesando documento 4355/10194
# Procesando documento 4356/10194
# Procesando documento 4357/10194
# Procesando documento 4358/10194
# Procesando documento 4359/10194
# Procesando documento 4360/10194
# Procesando documento 4361/10194
# Procesando documento 4362/10194
# Procesando documento 4363/10194
# Procesando documento 4364/10194
# Procesando documento 4365/10194
# Procesando documento 4366/10194
# Procesando documento 4367/10194
# Procesando documento 4368/10194
# Procesando documento 4369/10194
# Procesando documento 4370/10194
# Procesando documento 4371/10194
# Procesando documento 4372/10194
# Procesando documento 4373/10194
# Procesando documento 4374/10194
# Procesando documento 4375/10194
# Procesando documento 4376/10194
# Procesando documento 4377/10194
# Procesando documento 4378/10194
# Procesando documento 4379/10194
# Procesando documento 4380/10194
# Procesando documento 4381/10194
# Procesando documento 4382/10194
# Procesando documento 4383/10194
# Procesando documento 4384/10194
# Procesando documento 4385/10194
# Procesando documento 4386/10194
# Procesando documento 4387/10194
# Procesando documento 4388/10194
# Procesando documento 4389/10194
# Procesando documento 4390/10194
# Procesando documento 4391/10194
# Procesando documento 4392/10194
# Procesando documento 4393/10194
# Procesando documento 4394/10194
# Procesando documento 4395/10194
# Procesando documento 4396/10194
# Procesando documento 4397/10194
# Procesando documento 4398/10194
# Procesando documento 4399/10194
# Procesando documento 4400/10194
# Procesando documento 4401/10194
# Procesando documento 4402/10194
# Procesando documento 4403/10194
# Procesando documento 4404/10194
# Procesando documento 4405/10194
# Procesando documento 4406/10194
# Procesando documento 4407/10194
# Procesando documento 4408/10194
# Procesando documento 4409/10194
# Procesando documento 4410/10194
# Procesando documento 4411/10194
# Procesando documento 4412/10194
# Procesando documento 4413/10194
# Procesando documento 4414/10194
# Procesando documento 4415/10194
# Procesando documento 4416/10194
# Procesando documento 4417/10194
# Procesando documento 4418/10194
# Procesando documento 4419/10194
# Procesando documento 4420/10194
# Procesando documento 4421/10194
# Procesando documento 4422/10194
# Procesando documento 4423/10194
# Procesando documento 4424/10194
# Procesando documento 4425/10194
# Procesando documento 4426/10194
# Procesando documento 4427/10194
# Procesando documento 4428/10194
# Procesando documento 4429/10194
# Procesando documento 4430/10194
# Procesando documento 4431/10194
# Procesando documento 4432/10194
# Procesando documento 4433/10194
# Procesando documento 4434/10194
# Procesando documento 4435/10194
# Procesando documento 4436/10194
# Procesando documento 4437/10194
# Procesando documento 4438/10194
# Procesando documento 4439/10194
# Procesando documento 4440/10194
# Procesando documento 4441/10194
# Procesando documento 4442/10194
# Procesando documento 4443/10194
# Procesando documento 4444/10194
# Procesando documento 4445/10194
# Procesando documento 4446/10194
# Procesando documento 4447/10194
# Procesando documento 4448/10194
# Procesando documento 4449/10194
# Procesando documento 4450/10194
# Procesando documento 4451/10194
# Procesando documento 4452/10194
# Procesando documento 4453/10194
# Procesando documento 4454/10194
# Procesando documento 4455/10194
# Procesando documento 4456/10194
# Procesando documento 4457/10194
# Procesando documento 4458/10194
# Procesando documento 4459/10194
# Procesando documento 4460/10194
# Procesando documento 4461/10194
# Procesando documento 4462/10194
# Procesando documento 4463/10194
# Procesando documento 4464/10194
# Procesando documento 4465/10194
# Procesando documento 4466/10194
# Procesando documento 4467/10194
# Procesando documento 4468/10194
# Procesando documento 4469/10194
# Procesando documento 4470/10194
# Procesando documento 4471/10194
# Procesando documento 4472/10194
# Procesando documento 4473/10194
# Procesando documento 4474/10194
# Procesando documento 4475/10194
# Procesando documento 4476/10194
# Procesando documento 4477/10194
# Procesando documento 4478/10194
# Procesando documento 4479/10194
# Procesando documento 4480/10194
# Procesando documento 4481/10194
# Procesando documento 4482/10194
# Procesando documento 4483/10194
# Procesando documento 4484/10194
# Procesando documento 4485/10194
# Procesando documento 4486/10194
# Procesando documento 4487/10194
# Procesando documento 4488/10194
# Procesando documento 4489/10194
# Procesando documento 4490/10194
# Procesando documento 4491/10194
# Procesando documento 4492/10194
# Procesando documento 4493/10194
# Procesando documento 4494/10194
# Procesando documento 4495/10194
# Procesando documento 4496/10194
# Procesando documento 4497/10194
# Procesando documento 4498/10194
# Procesando documento 4499/10194
# Procesando documento 4500/10194
# Procesando documento 4501/10194
# Procesando documento 4502/10194
# Procesando documento 4503/10194
# Procesando documento 4504/10194
# Procesando documento 4505/10194
# Procesando documento 4506/10194
# Procesando documento 4507/10194
# Procesando documento 4508/10194
# Procesando documento 4509/10194
# Procesando documento 4510/10194
# Procesando documento 4511/10194
# Procesando documento 4512/10194
# Procesando documento 4513/10194
# Procesando documento 4514/10194
# Procesando documento 4515/10194
# Procesando documento 4516/10194
# Procesando documento 4517/10194
# Procesando documento 4518/10194
# Procesando documento 4519/10194
# Procesando documento 4520/10194
# Procesando documento 4521/10194
# Procesando documento 4522/10194
# Procesando documento 4523/10194
# Procesando documento 4524/10194
# Procesando documento 4525/10194
# Procesando documento 4526/10194
# Procesando documento 4527/10194
# Procesando documento 4528/10194
# Procesando documento 4529/10194
# Procesando documento 4530/10194
# Procesando documento 4531/10194
# Procesando documento 4532/10194
# Procesando documento 4533/10194
# Procesando documento 4534/10194
# Procesando documento 4535/10194
# Procesando documento 4536/10194
# Procesando documento 4537/10194
# Procesando documento 4538/10194
# Procesando documento 4539/10194
# Procesando documento 4540/10194
# Procesando documento 4541/10194
# Procesando documento 4542/10194
# Procesando documento 4543/10194
# Procesando documento 4544/10194
# Procesando documento 4545/10194
# Procesando documento 4546/10194
# Procesando documento 4547/10194
# Procesando documento 4548/10194
# Procesando documento 4549/10194
# Procesando documento 4550/10194
# Procesando documento 4551/10194
# Procesando documento 4552/10194
# Procesando documento 4553/10194
# Procesando documento 4554/10194
# Procesando documento 4555/10194
# Procesando documento 4556/10194
# Procesando documento 4557/10194
# Procesando documento 4558/10194
# Procesando documento 4559/10194
# Procesando documento 4560/10194
# Procesando documento 4561/10194
# Procesando documento 4562/10194
# Procesando documento 4563/10194
# Procesando documento 4564/10194
# Procesando documento 4565/10194
# Procesando documento 4566/10194
# Procesando documento 4567/10194
# Procesando documento 4568/10194
# Procesando documento 4569/10194
# Procesando documento 4570/10194
# Procesando documento 4571/10194
# Procesando documento 4572/10194
# Procesando documento 4573/10194
# Procesando documento 4574/10194
# Procesando documento 4575/10194
# Procesando documento 4576/10194
# Procesando documento 4577/10194
# Procesando documento 4578/10194
# Procesando documento 4579/10194
# Procesando documento 4580/10194
# Procesando documento 4581/10194
# Procesando documento 4582/10194
# Procesando documento 4583/10194
# Procesando documento 4584/10194
# Procesando documento 4585/10194
# Procesando documento 4586/10194
# Procesando documento 4587/10194
# Procesando documento 4588/10194
# Procesando documento 4589/10194
# Procesando documento 4590/10194
# Procesando documento 4591/10194
# Procesando documento 4592/10194
# Procesando documento 4593/10194
# Procesando documento 4594/10194
# Procesando documento 4595/10194
# Procesando documento 4596/10194
# Procesando documento 4597/10194
# Procesando documento 4598/10194
# Procesando documento 4599/10194
# Procesando documento 4600/10194
# Procesando documento 4601/10194
# Procesando documento 4602/10194
# Procesando documento 4603/10194
# Procesando documento 4604/10194
# Procesando documento 4605/10194
# Procesando documento 4606/10194
# Procesando documento 4607/10194
# Procesando documento 4608/10194
# Procesando documento 4609/10194
# Procesando documento 4610/10194
# Procesando documento 4611/10194
# Procesando documento 4612/10194
# Procesando documento 4613/10194
# Procesando documento 4614/10194
# Procesando documento 4615/10194
# Procesando documento 4616/10194
# Procesando documento 4617/10194
# Procesando documento 4618/10194
# Procesando documento 4619/10194
# Procesando documento 4620/10194
# Procesando documento 4621/10194
# Procesando documento 4622/10194
# Procesando documento 4623/10194
# Procesando documento 4624/10194
# Procesando documento 4625/10194
# Procesando documento 4626/10194
# Procesando documento 4627/10194
# Procesando documento 4628/10194
# Procesando documento 4629/10194
# Procesando documento 4630/10194
# Procesando documento 4631/10194
# Procesando documento 4632/10194
# Procesando documento 4633/10194
# Procesando documento 4634/10194
# Procesando documento 4635/10194
# Procesando documento 4636/10194
# Procesando documento 4637/10194
# Procesando documento 4638/10194
# Procesando documento 4639/10194
# Procesando documento 4640/10194
# Procesando documento 4641/10194
# Procesando documento 4642/10194
# Procesando documento 4643/10194
# Procesando documento 4644/10194
# Procesando documento 4645/10194
# Procesando documento 4646/10194
# Procesando documento 4647/10194
# Procesando documento 4648/10194
# Procesando documento 4649/10194
# Procesando documento 4650/10194
# Procesando documento 4651/10194
# Procesando documento 4652/10194
# Procesando documento 4653/10194
# Procesando documento 4654/10194
# Procesando documento 4655/10194
# Procesando documento 4656/10194
# Procesando documento 4657/10194
# Procesando documento 4658/10194
# Procesando documento 4659/10194
# Procesando documento 4660/10194
# Procesando documento 4661/10194
# Procesando documento 4662/10194
# Procesando documento 4663/10194
# Procesando documento 4664/10194
# Procesando documento 4665/10194
# Procesando documento 4666/10194
# Procesando documento 4667/10194
# Procesando documento 4668/10194
# Procesando documento 4669/10194
# Procesando documento 4670/10194
# Procesando documento 4671/10194
# Procesando documento 4672/10194
# Procesando documento 4673/10194
# Procesando documento 4674/10194
# Procesando documento 4675/10194
# Procesando documento 4676/10194
# Procesando documento 4677/10194
# Procesando documento 4678/10194
# Procesando documento 4679/10194
# Procesando documento 4680/10194
# Procesando documento 4681/10194
# Procesando documento 4682/10194
# Procesando documento 4683/10194
# Procesando documento 4684/10194
# Procesando documento 4685/10194
# Procesando documento 4686/10194
# Procesando documento 4687/10194
# Procesando documento 4688/10194
# Procesando documento 4689/10194
# Procesando documento 4690/10194
# Procesando documento 4691/10194
# Procesando documento 4692/10194
# Procesando documento 4693/10194
# Procesando documento 4694/10194
# Procesando documento 4695/10194
# Procesando documento 4696/10194
# Procesando documento 4697/10194
# Procesando documento 4698/10194
# Procesando documento 4699/10194
# Procesando documento 4700/10194
# Procesando documento 4701/10194
# Procesando documento 4702/10194
# Procesando documento 4703/10194
# Procesando documento 4704/10194
# Procesando documento 4705/10194
# Procesando documento 4706/10194
# Procesando documento 4707/10194
# Procesando documento 4708/10194
# Procesando documento 4709/10194
# Procesando documento 4710/10194
# Procesando documento 4711/10194
# Procesando documento 4712/10194
# Procesando documento 4713/10194
# Procesando documento 4714/10194
# Procesando documento 4715/10194
# Procesando documento 4716/10194
# Procesando documento 4717/10194
# Procesando documento 4718/10194
# Procesando documento 4719/10194
# Procesando documento 4720/10194
# Procesando documento 4721/10194
# Procesando documento 4722/10194
# Procesando documento 4723/10194
# Procesando documento 4724/10194
# Procesando documento 4725/10194
# Procesando documento 4726/10194
# Procesando documento 4727/10194
# Procesando documento 4728/10194
# Procesando documento 4729/10194
# Procesando documento 4730/10194
# Procesando documento 4731/10194
# Procesando documento 4732/10194
# Procesando documento 4733/10194
# Procesando documento 4734/10194
# Procesando documento 4735/10194
# Procesando documento 4736/10194
# Procesando documento 4737/10194
# Procesando documento 4738/10194
# Procesando documento 4739/10194
# Procesando documento 4740/10194
# Procesando documento 4741/10194
# Procesando documento 4742/10194
# Procesando documento 4743/10194
# Procesando documento 4744/10194
# Procesando documento 4745/10194
# Procesando documento 4746/10194
# Procesando documento 4747/10194
# Procesando documento 4748/10194
# Procesando documento 4749/10194
# Procesando documento 4750/10194
# Procesando documento 4751/10194
# Procesando documento 4752/10194
# Procesando documento 4753/10194
# Procesando documento 4754/10194
# Procesando documento 4755/10194
# Procesando documento 4756/10194
# Procesando documento 4757/10194
# Procesando documento 4758/10194
# Procesando documento 4759/10194
# Procesando documento 4760/10194
# Procesando documento 4761/10194
# Procesando documento 4762/10194
# Procesando documento 4763/10194
# Procesando documento 4764/10194
# Procesando documento 4765/10194
# Procesando documento 4766/10194
# Procesando documento 4767/10194
# Procesando documento 4768/10194
# Procesando documento 4769/10194
# Procesando documento 4770/10194
# Procesando documento 4771/10194
# Procesando documento 4772/10194
# Procesando documento 4773/10194
# Procesando documento 4774/10194
# Procesando documento 4775/10194
# Procesando documento 4776/10194
# Procesando documento 4777/10194
# Procesando documento 4778/10194
# Procesando documento 4779/10194
# Procesando documento 4780/10194
# Procesando documento 4781/10194
# Procesando documento 4782/10194
# Procesando documento 4783/10194
# Procesando documento 4784/10194
# Procesando documento 4785/10194
# Procesando documento 4786/10194
# Procesando documento 4787/10194
# Procesando documento 4788/10194
# Procesando documento 4789/10194
# Procesando documento 4790/10194
# Procesando documento 4791/10194
# Procesando documento 4792/10194
# Procesando documento 4793/10194
# Procesando documento 4794/10194
# Procesando documento 4795/10194
# Procesando documento 4796/10194
# Procesando documento 4797/10194
# Procesando documento 4798/10194
# Procesando documento 4799/10194
# Procesando documento 4800/10194
# Procesando documento 4801/10194
# Procesando documento 4802/10194
# Procesando documento 4803/10194
# Procesando documento 4804/10194
# Procesando documento 4805/10194
# Procesando documento 4806/10194
# Procesando documento 4807/10194
# Procesando documento 4808/10194
# Procesando documento 4809/10194
# Procesando documento 4810/10194
# Procesando documento 4811/10194
# Procesando documento 4812/10194
# Procesando documento 4813/10194
# Procesando documento 4814/10194
# Procesando documento 4815/10194
# Procesando documento 4816/10194
# Procesando documento 4817/10194
# Procesando documento 4818/10194
# Procesando documento 4819/10194
# Procesando documento 4820/10194
# Procesando documento 4821/10194
# Procesando documento 4822/10194
# Procesando documento 4823/10194
# Procesando documento 4824/10194
# Procesando documento 4825/10194
# Procesando documento 4826/10194
# Procesando documento 4827/10194
# Procesando documento 4828/10194
# Procesando documento 4829/10194
# Procesando documento 4830/10194
# Procesando documento 4831/10194
# Procesando documento 4832/10194
# Procesando documento 4833/10194
# Procesando documento 4834/10194
# Procesando documento 4835/10194
# Procesando documento 4836/10194
# Procesando documento 4837/10194
# Procesando documento 4838/10194
# Procesando documento 4839/10194
# Procesando documento 4840/10194
# Procesando documento 4841/10194
# Procesando documento 4842/10194
# Procesando documento 4843/10194
# Procesando documento 4844/10194
# Procesando documento 4845/10194
# Procesando documento 4846/10194
# Procesando documento 4847/10194
# Procesando documento 4848/10194
# Procesando documento 4849/10194
# Procesando documento 4850/10194
# Procesando documento 4851/10194
# Procesando documento 4852/10194
# Procesando documento 4853/10194
# Procesando documento 4854/10194
# Procesando documento 4855/10194
# Procesando documento 4856/10194
# Procesando documento 4857/10194
# Procesando documento 4858/10194
# Procesando documento 4859/10194
# Procesando documento 4860/10194
# Procesando documento 4861/10194
# Procesando documento 4862/10194
# Procesando documento 4863/10194
# Procesando documento 4864/10194
# Procesando documento 4865/10194
# Procesando documento 4866/10194
# Procesando documento 4867/10194
# Procesando documento 4868/10194
# Procesando documento 4869/10194
# Procesando documento 4870/10194
# Procesando documento 4871/10194
# Procesando documento 4872/10194
# Procesando documento 4873/10194
# Procesando documento 4874/10194
# Procesando documento 4875/10194
# Procesando documento 4876/10194
# Procesando documento 4877/10194
# Procesando documento 4878/10194
# Procesando documento 4879/10194
# Procesando documento 4880/10194
# Procesando documento 4881/10194
# Procesando documento 4882/10194
# Procesando documento 4883/10194
# Procesando documento 4884/10194
# Procesando documento 4885/10194
# Procesando documento 4886/10194
# Procesando documento 4887/10194
# Procesando documento 4888/10194
# Procesando documento 4889/10194
# Procesando documento 4890/10194
# Procesando documento 4891/10194
# Procesando documento 4892/10194
# Procesando documento 4893/10194
# Procesando documento 4894/10194
# Procesando documento 4895/10194
# Procesando documento 4896/10194
# Procesando documento 4897/10194
# Procesando documento 4898/10194
# Procesando documento 4899/10194
# Procesando documento 4900/10194
# Procesando documento 4901/10194
# Procesando documento 4902/10194
# Procesando documento 4903/10194
# Procesando documento 4904/10194
# Procesando documento 4905/10194
# Procesando documento 4906/10194
# Procesando documento 4907/10194
# Procesando documento 4908/10194
# Procesando documento 4909/10194
# Procesando documento 4910/10194
# Procesando documento 4911/10194
# Procesando documento 4912/10194
# Procesando documento 4913/10194
# Procesando documento 4914/10194
# Procesando documento 4915/10194
# Procesando documento 4916/10194
# Procesando documento 4917/10194
# Procesando documento 4918/10194
# Procesando documento 4919/10194
# Procesando documento 4920/10194
# Procesando documento 4921/10194
# Procesando documento 4922/10194
# Procesando documento 4923/10194
# Procesando documento 4924/10194
# Procesando documento 4925/10194
# Procesando documento 4926/10194
# Procesando documento 4927/10194
# Procesando documento 4928/10194
# Procesando documento 4929/10194
# Procesando documento 4930/10194
# Procesando documento 4931/10194
# Procesando documento 4932/10194
# Procesando documento 4933/10194
# Procesando documento 4934/10194
# Procesando documento 4935/10194
# Procesando documento 4936/10194
# Procesando documento 4937/10194
# Procesando documento 4938/10194
# Procesando documento 4939/10194
# Procesando documento 4940/10194
# Procesando documento 4941/10194
# Procesando documento 4942/10194
# Procesando documento 4943/10194
# Procesando documento 4944/10194
# Procesando documento 4945/10194
# Procesando documento 4946/10194
# Procesando documento 4947/10194
# Procesando documento 4948/10194
# Procesando documento 4949/10194
# Procesando documento 4950/10194
# Procesando documento 4951/10194
# Procesando documento 4952/10194
# Procesando documento 4953/10194
# Procesando documento 4954/10194
# Procesando documento 4955/10194
# Procesando documento 4956/10194
# Procesando documento 4957/10194
# Procesando documento 4958/10194
# Procesando documento 4959/10194
# Procesando documento 4960/10194
# Procesando documento 4961/10194
# Procesando documento 4962/10194
# Procesando documento 4963/10194
# Procesando documento 4964/10194
# Procesando documento 4965/10194
# Procesando documento 4966/10194
# Procesando documento 4967/10194
# Procesando documento 4968/10194
# Procesando documento 4969/10194
# Procesando documento 4970/10194
# Procesando documento 4971/10194
# Procesando documento 4972/10194
# Procesando documento 4973/10194
# Procesando documento 4974/10194
# Procesando documento 4975/10194
# Procesando documento 4976/10194
# Procesando documento 4977/10194
# Procesando documento 4978/10194
# Procesando documento 4979/10194
# Procesando documento 4980/10194
# Procesando documento 4981/10194
# Procesando documento 4982/10194
# Procesando documento 4983/10194
# Procesando documento 4984/10194
# Procesando documento 4985/10194
# Procesando documento 4986/10194
# Procesando documento 4987/10194
# Procesando documento 4988/10194
# Procesando documento 4989/10194
# Procesando documento 4990/10194
# Procesando documento 4991/10194
# Procesando documento 4992/10194
# Procesando documento 4993/10194
# Procesando documento 4994/10194
# Procesando documento 4995/10194
# Procesando documento 4996/10194
# Procesando documento 4997/10194
# Procesando documento 4998/10194
# Procesando documento 4999/10194
# Procesando documento 5000/10194
# Procesando documento 5001/10194
# Procesando documento 5002/10194
# Procesando documento 5003/10194
# Procesando documento 5004/10194
# Procesando documento 5005/10194
# Procesando documento 5006/10194
# Procesando documento 5007/10194
# Procesando documento 5008/10194
# Procesando documento 5009/10194
# Procesando documento 5010/10194
# Procesando documento 5011/10194
# Procesando documento 5012/10194
# ...
# Procesando documento 8015/10194
# Procesando documento 8016/10194
# Procesando documento 8017/10194
# Procesando documento 8018/10194
# Procesando documento 8019/10194
# Procesando documento 8020/10194
# Procesando documento 8021/10194
# Procesando documento 8022/10194
# Procesando documento 8023/10194
# Procesando documento 8024/10194
# Procesando documento 8025/10194
# Procesando documento 8026/10194
# Procesando documento 8027/10194
# Procesando documento 8028/10194
# Procesando documento 8029/10194
# Procesando documento 8030/10194
# Procesando documento 8031/10194
# Procesando documento 8032/10194
# Procesando documento 8033/10194
# Procesando documento 8034/10194
# Procesando documento 8035/10194
# Procesando documento 8036/10194
# Procesando documento 8037/10194
# Procesando documento 8038/10194
# Procesando documento 8039/10194
# Procesando documento 8040/10194
# Procesando documento 8041/10194
# Procesando documento 8042/10194
# Procesando documento 8043/10194
# Procesando documento 8044/10194
# Procesando documento 8045/10194
# Procesando documento 8046/10194
# Procesando documento 8047/10194
# Procesando documento 8048/10194
# Procesando documento 8049/10194
# Procesando documento 8050/10194
# Procesando documento 8051/10194
# Procesando documento 8052/10194
# Procesando documento 8053/10194
# Procesando documento 8054/10194
# Procesando documento 8055/10194
# Procesando documento 8056/10194
# Procesando documento 8057/10194
# Procesando documento 8058/10194
# Procesando documento 8059/10194
# Procesando documento 8060/10194
# Procesando documento 8061/10194
# Procesando documento 8062/10194
# Procesando documento 8063/10194
# Procesando documento 8064/10194
# Procesando documento 8065/10194
# Procesando documento 8066/10194
# Procesando documento 8067/10194
# Procesando documento 8068/10194
# Procesando documento 8069/10194
# Procesando documento 8070/10194
# Procesando documento 8071/10194
# Procesando documento 8072/10194
# Procesando documento 8073/10194
# Procesando documento 8074/10194
# Procesando documento 8075/10194
# Procesando documento 8076/10194
# Procesando documento 8077/10194
# Procesando documento 8078/10194
# Procesando documento 8079/10194
# Procesando documento 8080/10194
# Procesando documento 8081/10194
# Procesando documento 8082/10194
# Procesando documento 8083/10194
# Procesando documento 8084/10194
# Procesando documento 8085/10194
# Procesando documento 8086/10194
# Procesando documento 8087/10194
# Procesando documento 8088/10194
# Procesando documento 8089/10194
# Procesando documento 8090/10194
# Procesando documento 8091/10194
# Procesando documento 8092/10194
# Procesando documento 8093/10194
# Procesando documento 8094/10194
# Procesando documento 8095/10194
# Procesando documento 8096/10194
# Procesando documento 8097/10194
# Procesando documento 8098/10194
# Procesando documento 8099/10194
# Procesando documento 8100/10194
# Procesando documento 8101/10194
# Procesando documento 8102/10194
# Procesando documento 8103/10194
# Procesando documento 8104/10194
# Procesando documento 8105/10194
# Procesando documento 8106/10194
# Procesando documento 8107/10194
# Procesando documento 8108/10194
# Procesando documento 8109/10194
# Procesando documento 8110/10194
# Procesando documento 8111/10194
# Procesando documento 8112/10194
# Procesando documento 8113/10194
# Procesando documento 8114/10194
# Procesando documento 8115/10194
# Procesando documento 8116/10194
# Procesando documento 8117/10194
# Procesando documento 8118/10194
# Procesando documento 8119/10194
# Procesando documento 8120/10194
# Procesando documento 8121/10194
# Procesando documento 8122/10194
# Procesando documento 8123/10194
# Procesando documento 8124/10194
# Procesando documento 8125/10194
# Procesando documento 8126/10194
# Procesando documento 8127/10194
# Procesando documento 8128/10194
# Procesando documento 8129/10194
# Procesando documento 8130/10194
# Procesando documento 8131/10194
# Procesando documento 8132/10194
# Procesando documento 8133/10194
# Procesando documento 8134/10194
# Procesando documento 8135/10194
# Procesando documento 8136/10194
# Procesando documento 8137/10194
# Procesando documento 8138/10194
# Procesando documento 8139/10194
# Procesando documento 8140/10194
# Procesando documento 8141/10194
# Procesando documento 8142/10194
# Procesando documento 8143/10194
# Procesando documento 8144/10194
# Procesando documento 8145/10194
# Procesando documento 8146/10194
# Procesando documento 8147/10194
# Procesando documento 8148/10194
# Procesando documento 8149/10194
# Procesando documento 8150/10194
# Procesando documento 8151/10194
# Procesando documento 8152/10194
# Procesando documento 8153/10194
# Procesando documento 8154/10194
# Procesando documento 8155/10194
# Procesando documento 8156/10194
# Procesando documento 8157/10194
# Procesando documento 8158/10194
# Procesando documento 8159/10194
# Procesando documento 8160/10194
# Procesando documento 8161/10194
# Procesando documento 8162/10194
# Procesando documento 8163/10194
# Procesando documento 8164/10194
# Procesando documento 8165/10194
# Procesando documento 8166/10194
# Procesando documento 8167/10194
# Procesando documento 8168/10194
# Procesando documento 8169/10194
# Procesando documento 8170/10194
# Procesando documento 8171/10194
# Procesando documento 8172/10194
# Procesando documento 8173/10194
# Procesando documento 8174/10194
# Procesando documento 8175/10194
# Procesando documento 8176/10194
# Procesando documento 8177/10194
# Procesando documento 8178/10194
# Procesando documento 8179/10194
# Procesando documento 8180/10194
# Procesando documento 8181/10194
# Procesando documento 8182/10194
# Procesando documento 8183/10194
# Procesando documento 8184/10194
# Procesando documento 8185/10194
# Procesando documento 8186/10194
# Procesando documento 8187/10194
# Procesando documento 8188/10194
# Procesando documento 8189/10194
# Procesando documento 8190/10194
# Procesando documento 8191/10194
# Procesando documento 8192/10194
# Procesando documento 8193/10194
# Procesando documento 8194/10194
# Procesando documento 8195/10194
# Procesando documento 8196/10194
# Procesando documento 8197/10194
# Procesando documento 8198/10194
# Procesando documento 8199/10194
# Procesando documento 8200/10194
# Procesando documento 8201/10194
# Procesando documento 8202/10194
# Procesando documento 8203/10194
# Procesando documento 8204/10194
# Procesando documento 8205/10194
# Procesando documento 8206/10194
# Procesando documento 8207/10194
# Procesando documento 8208/10194
# Procesando documento 8209/10194
# Procesando documento 8210/10194
# Procesando documento 8211/10194
# Procesando documento 8212/10194
# Procesando documento 8213/10194
# Procesando documento 8214/10194
# Procesando documento 8215/10194
# Procesando documento 8216/10194
# Procesando documento 8217/10194
# Procesando documento 8218/10194
# Procesando documento 8219/10194
# Procesando documento 8220/10194
# Procesando documento 8221/10194
# Procesando documento 8222/10194
# Procesando documento 8223/10194
# Procesando documento 8224/10194
# Procesando documento 8225/10194
# Procesando documento 8226/10194
# Procesando documento 8227/10194
# Procesando documento 8228/10194
# Procesando documento 8229/10194
# Procesando documento 8230/10194
# Procesando documento 8231/10194
# Procesando documento 8232/10194
# Procesando documento 8233/10194
# Procesando documento 8234/10194
# Procesando documento 8235/10194
# Procesando documento 8236/10194
# Procesando documento 8237/10194
# Procesando documento 8238/10194
# Procesando documento 8239/10194
# Procesando documento 8240/10194
# Procesando documento 8241/10194
# Procesando documento 8242/10194
# Procesando documento 8243/10194
# Procesando documento 8244/10194
# Procesando documento 8245/10194
# Procesando documento 8246/10194
# Procesando documento 8247/10194
# Procesando documento 8248/10194
# Procesando documento 8249/10194
# Procesando documento 8250/10194
# Procesando documento 8251/10194
# Procesando documento 8252/10194
# Procesando documento 8253/10194
# Procesando documento 8254/10194
# Procesando documento 8255/10194
# Procesando documento 8256/10194
# Procesando documento 8257/10194
# Procesando documento 8258/10194
# Procesando documento 8259/10194
# Procesando documento 8260/10194
# Procesando documento 8261/10194
# Procesando documento 8262/10194
# Procesando documento 8263/10194
# Procesando documento 8264/10194
# Procesando documento 8265/10194
# Procesando documento 8266/10194
# Procesando documento 8267/10194
# Procesando documento 8268/10194
# Procesando documento 8269/10194
# Procesando documento 8270/10194
# Procesando documento 8271/10194
# Procesando documento 8272/10194
# Procesando documento 8273/10194
# Procesando documento 8274/10194
# Procesando documento 8275/10194
# Procesando documento 8276/10194
# Procesando documento 8277/10194
# Procesando documento 8278/10194
# Procesando documento 8279/10194
# Procesando documento 8280/10194
# Procesando documento 8281/10194
# Procesando documento 8282/10194
# Procesando documento 8283/10194
# Procesando documento 8284/10194
# Procesando documento 8285/10194
# Procesando documento 8286/10194
# Procesando documento 8287/10194
# Procesando documento 8288/10194
# Procesando documento 8289/10194
# Procesando documento 8290/10194
# Procesando documento 8291/10194
# Procesando documento 8292/10194
# Procesando documento 8293/10194
# Procesando documento 8294/10194
# Procesando documento 8295/10194
# Procesando documento 8296/10194
# Procesando documento 8297/10194
# Procesando documento 8298/10194
# Procesando documento 8299/10194
# Procesando documento 8300/10194
# Procesando documento 8301/10194
# Procesando documento 8302/10194
# Procesando documento 8303/10194
# Procesando documento 8304/10194
# Procesando documento 8305/10194
# Procesando documento 8306/10194
# Procesando documento 8307/10194
# Procesando documento 8308/10194
# Procesando documento 8309/10194
# Procesando documento 8310/10194
# Procesando documento 8311/10194
# Procesando documento 8312/10194
# Procesando documento 8313/10194
# Procesando documento 8314/10194
# Procesando documento 8315/10194
# Procesando documento 8316/10194
# Procesando documento 8317/10194
# Procesando documento 8318/10194
# Procesando documento 8319/10194
# Procesando documento 8320/10194
# Procesando documento 8321/10194
# Procesando documento 8322/10194
# Procesando documento 8323/10194
# Procesando documento 8324/10194
# Procesando documento 8325/10194
# Procesando documento 8326/10194
# Procesando documento 8327/10194
# Procesando documento 8328/10194
# Procesando documento 8329/10194
# Procesando documento 8330/10194
# Procesando documento 8331/10194
# Procesando documento 8332/10194
# Procesando documento 8333/10194
# Procesando documento 8334/10194
# Procesando documento 8335/10194
# Procesando documento 8336/10194
# Procesando documento 8337/10194
# Procesando documento 8338/10194
# Procesando documento 8339/10194
# Procesando documento 8340/10194
# Procesando documento 8341/10194
# Procesando documento 8342/10194
# Procesando documento 8343/10194
# Procesando documento 8344/10194
# Procesando documento 8345/10194
# Procesando documento 8346/10194
# Procesando documento 8347/10194
# Procesando documento 8348/10194
# Procesando documento 8349/10194
# Procesando documento 8350/10194
# Procesando documento 8351/10194
# Procesando documento 8352/10194
# Procesando documento 8353/10194
# Procesando documento 8354/10194
# Procesando documento 8355/10194
# Procesando documento 8356/10194
# Procesando documento 8357/10194
# Procesando documento 8358/10194
# Procesando documento 8359/10194
# Procesando documento 8360/10194
# Procesando documento 8361/10194
# Procesando documento 8362/10194
# Procesando documento 8363/10194
# Procesando documento 8364/10194
# Procesando documento 8365/10194
# Procesando documento 8366/10194
# Procesando documento 8367/10194
# Procesando documento 8368/10194
# Procesando documento 8369/10194
# Procesando documento 8370/10194
# Procesando documento 8371/10194
# Procesando documento 8372/10194
# Procesando documento 8373/10194
# Procesando documento 8374/10194
# Procesando documento 8375/10194
# Procesando documento 8376/10194
# Procesando documento 8377/10194
# Procesando documento 8378/10194
# Procesando documento 8379/10194
# Procesando documento 8380/10194
# Procesando documento 8381/10194
# Procesando documento 8382/10194
# Procesando documento 8383/10194
# Procesando documento 8384/10194
# Procesando documento 8385/10194
# Procesando documento 8386/10194
# Procesando documento 8387/10194
# Procesando documento 8388/10194
# Procesando documento 8389/10194
# Procesando documento 8390/10194
# Procesando documento 8391/10194
# Procesando documento 8392/10194
# Procesando documento 8393/10194
# Procesando documento 8394/10194
# Procesando documento 8395/10194
# Procesando documento 8396/10194
# Procesando documento 8397/10194
# Procesando documento 8398/10194
# Procesando documento 8399/10194
# Procesando documento 8400/10194
# Procesando documento 8401/10194
# Procesando documento 8402/10194
# Procesando documento 8403/10194
# Procesando documento 8404/10194
# Procesando documento 8405/10194
# Procesando documento 8406/10194
# Procesando documento 8407/10194
# Procesando documento 8408/10194
# Procesando documento 8409/10194
# Procesando documento 8410/10194
# Procesando documento 8411/10194
# Procesando documento 8412/10194
# Procesando documento 8413/10194
# Procesando documento 8414/10194
# Procesando documento 8415/10194
# Procesando documento 8416/10194
# Procesando documento 8417/10194
# Procesando documento 8418/10194
# Procesando documento 8419/10194
# Procesando documento 8420/10194
# Procesando documento 8421/10194
# Procesando documento 8422/10194
# Procesando documento 8423/10194
# Procesando documento 8424/10194
# Procesando documento 8425/10194
# Procesando documento 8426/10194
# Procesando documento 8427/10194
# Procesando documento 8428/10194
# Procesando documento 8429/10194
# Procesando documento 8430/10194
# Procesando documento 8431/10194
# Procesando documento 8432/10194
# Procesando documento 8433/10194
# Procesando documento 8434/10194
# Procesando documento 8435/10194
# Procesando documento 8436/10194
# Procesando documento 8437/10194
# Procesando documento 8438/10194
# Procesando documento 8439/10194
# Procesando documento 8440/10194
# Procesando documento 8441/10194
# Procesando documento 8442/10194
# Procesando documento 8443/10194
# Procesando documento 8444/10194
# Procesando documento 8445/10194
# Procesando documento 8446/10194
# Procesando documento 8447/10194
# Procesando documento 8448/10194
# Procesando documento 8449/10194
# Procesando documento 8450/10194
# Procesando documento 8451/10194
# Procesando documento 8452/10194
# Procesando documento 8453/10194
# Procesando documento 8454/10194
# Procesando documento 8455/10194
# Procesando documento 8456/10194
# Procesando documento 8457/10194
# Procesando documento 8458/10194
# Procesando documento 8459/10194
# Procesando documento 8460/10194
# Procesando documento 8461/10194
# Procesando documento 8462/10194
# Procesando documento 8463/10194
# Procesando documento 8464/10194
# Procesando documento 8465/10194
# Procesando documento 8466/10194
# Procesando documento 8467/10194
# Procesando documento 8468/10194
# Procesando documento 8469/10194
# Procesando documento 8470/10194
# Procesando documento 8471/10194
# Procesando documento 8472/10194
# Procesando documento 8473/10194
# Procesando documento 8474/10194
# Procesando documento 8475/10194
# Procesando documento 8476/10194
# Procesando documento 8477/10194
# Procesando documento 8478/10194
# Procesando documento 8479/10194
# Procesando documento 8480/10194
# Procesando documento 8481/10194
# Procesando documento 8482/10194
# Procesando documento 8483/10194
# Procesando documento 8484/10194
# Procesando documento 8485/10194
# Procesando documento 8486/10194
# Procesando documento 8487/10194
# Procesando documento 8488/10194
# Procesando documento 8489/10194
# Procesando documento 8490/10194
# Procesando documento 8491/10194
# Procesando documento 8492/10194
# Procesando documento 8493/10194
# Procesando documento 8494/10194
# Procesando documento 8495/10194
# Procesando documento 8496/10194
# Procesando documento 8497/10194
# Procesando documento 8498/10194
# Procesando documento 8499/10194
# Procesando documento 8500/10194
# Procesando documento 8501/10194
# Procesando documento 8502/10194
# Procesando documento 8503/10194
# Procesando documento 8504/10194
# Procesando documento 8505/10194
# Procesando documento 8506/10194
# Procesando documento 8507/10194
# Procesando documento 8508/10194
# Procesando documento 8509/10194
# Procesando documento 8510/10194
# Procesando documento 8511/10194
# Procesando documento 8512/10194
# Procesando documento 8513/10194
# Procesando documento 8514/10194
